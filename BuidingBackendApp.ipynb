# %% [markdown]
# Context:
# Name of the project
# What it will be created, Understand the main requirements, generate the main Idea.
# Choose architecture, and database, framework
# Separate into main clases (entities)
# For Layered:
# Domain, Infrastructure, Application, API
#
# ✅ Checklist de Implementación
#
# Solución y proyectos creados
# Referencias configuradas
# Paquetes NuGet instalados
# DB Context y repositorios implementados
# Servicios y DTOs definidos
# Controladores configurados
# JWT/Swagger funcionando
# Tests pasando
#
# Development:
# Previous requirements -> Verify if the next tools, frameworks are available:
# Dotnet
#
# dotnet --version
# Download & install .net 8 is needed.

# %%
#Crear solucion
dotnet new sln -n WorkModel

# Crear proyectos
dotnet new classlib -n WorkModel.Domain
dotnet new classlib -n WorkModel.Application
dotnet new classlib -n WorkModel.Data
dotnet new API -n WorkModel.API


#Crear Tests:
dotnet new xunit -n WorkModel.Test

#Agregar proyectosa la solución
dotnet sln add WorkModel.Domain
dotnet sln add WorkModel.Data
dotnet sln add WorkModel.Application
dotnet sln add WorkModel.API

#2.Agregar Referencias entre Proyectos

# API -> Aplication
dotnet add <API> reference <Application>

# Application -> Domain
dotnet add <Application> reference <Domain>

# Infrastructure -> Domain
dotnet add <Infrastructure> reference <Domain>

# Test -> All neccessary projects
dotnet add <Test> reference <Application Domain>

Summary:
API -> Application -> Domain | Infrastructure -> Domain

Test -> *

## Instalacion de todos los paquetes NuGets.# Paquetes esenciales (Generales)
dotnet add package Microsoft.EntityFrameworkCore --version <ver>
dotnet add package AutoMapper
dotnet add package FluentValidation

## Specific by layers:
#API
dotnet add WorkModel.API/ package Swashbuclkle.AspNetCore
dotnet add WorkModel.API/ package Microsof.AspNetCiro.Authentication.JwtBearer
dotnet add WorkModel.API/ package AspNetCoreRateLimit

#Infrastructure Layer
dotnet add WorkModel.Infrastructure/ package Microsof.EntityFrameworkCore.SqlServer
dotnet add WorkModel.Infrastructure/ package Microsoft.Extensions.Identity.Core

#Tests
dotnet add WorkModel.Tests/ package Moq
dotnet add WorkModel.Tests/ package FluentAssertions


📦 solutions/
├── 📦 WorkModel/                  ← Solución principal
│   ├── WorkModel.API/
│   ├── WorkModel.Application/
│   ├── WorkModel.Domain/
│   └── WorkModel.Infrastructure/
│
└── 📦 WorkModel.Tests/            ← Solución de tests independiente
    ├── WorkModel.UnitTests/       ← Tests unitarios
    └── WorkModel.IntegrationTests/ ← Tests de integración

# %%
{
  "userId": "b6a11ac2-38e4-4eb3-971d-6fbd999e726e",
  "firstName": "John",
  "lastName": "Doe",
  "userName": "johndoe",
  "email": "johndoe@example.com",
  "role": "User",
  "token": "eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9..NuhSyvZOW-AAQG4oTQ_iY4FTdsLXThNh3TjNwcjnC5Y"
}

# %%
dotnet new xunit -n HotelReservation.Tests
dotnet sln add HotelReservation.Tests/HotelReservation.Tests.csproj
dotnet add HotelReservation.Tests reference HotelReservation.Application
