# %% [markdown]
# Creacion de Backend:
#
# 1. Crear carpeta contenedora: Portfolio
# 2. Crear subcarpeta Backend
# 3. Crear solucion del proyecto
# 4. Crear Capas del projecto: Domain, Application, Infrastructure, API, Shared.
# 5. Dentro de Shared crear una capa de Validation.
# 6. Crear aparte un folder de testeo.
# 7. Iniciar con el patron, authentication
# 8.  Crear carpeta Entities/ {EntityBase, User, Role}
# 9.  Crear folder de interfaces
# 10. Crear Persistance/Data/WorkModelDbContext.
# 11. Crear Repositories/ RoleRepository
# 12. Crear Repository/ UserRepository
# 13. Crear Entity/ Services/ IJwtTokenGenerator
# 14. Crear Repositories/ IRoleRepository & IUserRepository.
# 15. Crear JwtTokenGenerator
# 16. Crear Authentication/ Role & User
# 17. Crear WorkModel.Application/DTO/ Login & RegisterRequest
# 18. Crear WorkModel.Application/Auth/Commands/LoginCommand & LoginCommandHandler & RegisterCommand & ResgisterCommandHandler
# 19. Crear AuthResult
#
# 23. Crear AuthController
# 24. Crear Validation
# 25. Crear Result Page
#
# mkdir BaseTaskManagementAppBackend
# dotnet new webapi WorkModel.API
# dotnet new classlib WorkModel.Domain
# dotnet new classlib WorkModel.Application
# dotnet new classlib WorkModel.Infrastructure
#
# dotnet add WorkModel.API reference WorkModel.Application
# dotnet add WorkModel.Application reference WorkModel.Infrastructure
# dotnet add WorkModel.Infrastructure reference WorkModel.Domain
# dotnet add WorkModel.Application reference WorkModel.Domain
#
# dotnet new sln -n WorkModel
#
# dotnet sln WorkModel.sln add WorkModel.API
# dotnet sln WorkModel.sln add WorkModel.Domain
# dotnet sln WorkModel.sln add WorkModel.Application
# dotnet sln WorkModel.sln add WorkModel.Infrastructure
#
# dotnet add package Pomelo.EntityFrameworkCore.MySql --version 7.0.0
# dotnet add package Microsoft.EntityFrameworkCore.Design
# dotnet add package Microsoft.AspNetCore.Authentication.JwtBearer
# dotnet add package Microsoft.Extensions.Options.ConfigurationExtensions
# dotnet add package System.IdentityModel.Tokens.Jwt
# dotnet add package BCrypt.Net-Next
# dotnet add package Microsoft.AspNetCore.Mvc.Testing
#
# openssl rand -base64 64
# brew services start mysql
#
# dotnet ef migrations add InitialCreate
# dotnet tool install --global dotnet-ef
#
# dotnet ef migrations add InitialCreate --project WorkModel.Infrastructure/WorkModel.Infrastructure.csproj --startup-project WorkModel.API/WorkModel.API.csproj
#
# dotnet ef migrations add InitialCreate --project WorkModel.Infrastructure --startup-project WorkModel.API
#
# dotnet ef database update add InitialCreate --project WorkModel.Infrastructure --startup-project WorkModel.API
#
# dotnet new xunit -n WorkModel.Application.Tests
#
# dotnet sln add WorkModel.Application.Tests/WorkModel.Application.Tests.csproj
